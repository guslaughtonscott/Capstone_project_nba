# %%
# %pip install optuna
# Out:
# Requirement already satisfied: optuna in c:\users\ollyl-s\appdata\local\anaconda3\lib\site-packages (4.6.0)
# Requirement already satisfied: alembic>=1.5.0 in c:\users\ollyl-s\appdata\local\anaconda3\lib\site-packages (from optuna) (1.17.2)
# Requirement already satisfied: colorlog in c:\users\ollyl-s\appdata\local\anaconda3\lib\site-packages (from optuna) (6.10.1)
# Requirement already satisfied: numpy in c:\users\ollyl-s\appdata\local\anaconda3\lib\site-packages (from optuna) (2.1.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\ollyl-s\appdata\local\anaconda3\lib\site-packages (from optuna) (24.2)
# Requirement already satisfied: sqlalchemy>=1.4.2 in c:\users\ollyl-s\appdata\local\anaconda3\lib\site-packages (from optuna) (2.0.39)
# Requirement already satisfied: tqdm in c:\users\ollyl-s\appdata\local\anaconda3\lib\site-packages (from optuna) (4.67.1)
# Requirement already satisfied: PyYAML in c:\users\ollyl-s\appdata\local\anaconda3\lib\site-packages (from optuna) (6.0.2)
# Requirement already satisfied: Mako in c:\users\ollyl-s\appdata\local\anaconda3\lib\site-packages (from alembic>=1.5.0->optuna) (1.3.10)
# Requirement already satisfied: typing-extensions>=4.12 in c:\users\ollyl-s\appdata\local\anaconda3\lib\site-packages (from alembic>=1.5.0->optuna) (4.12.2)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\ollyl-s\appdata\local\anaconda3\lib\site-packages (from sqlalchemy>=1.4.2->optuna) (3.1.1)
# Requirement already satisfied: colorama in c:\users\ollyl-s\appdata\local\anaconda3\lib\site-packages (from colorlog->optuna) (0.4.6)
# Requirement already satisfied: MarkupSafe>=0.9.2 in c:\users\ollyl-s\appdata\local\anaconda3\lib\site-packages (from Mako->alembic>=1.5.0->optuna) (3.0.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install -U gus-nba-tools
# Out:
# Requirement already satisfied: gus-nba-tools in c:\users\ollyl-s\appdata\local\anaconda3\lib\site-packages (0.2.3)
# Requirement already satisfied: pandas in c:\users\ollyl-s\appdata\local\anaconda3\lib\site-packages (from gus-nba-tools) (2.2.3)
# Requirement already satisfied: nba_api in c:\users\ollyl-s\appdata\local\anaconda3\lib\site-packages (from gus-nba-tools) (1.11.3)
# Requirement already satisfied: numpy>=2.1.0 in c:\users\ollyl-s\appdata\local\anaconda3\lib\site-packages (from nba_api->gus-nba-tools) (2.1.3)
# Requirement already satisfied: requests<3.0.0,>=2.32.3 in c:\users\ollyl-s\appdata\local\anaconda3\lib\site-packages (from nba_api->gus-nba-tools) (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\ollyl-s\appdata\local\anaconda3\lib\site-packages (from requests<3.0.0,>=2.32.3->nba_api->gus-nba-tools) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ollyl-s\appdata\local\anaconda3\lib\site-packages (from requests<3.0.0,>=2.32.3->nba_api->gus-nba-tools) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\ollyl-s\appdata\local\anaconda3\lib\site-packages (from requests<3.0.0,>=2.32.3->nba_api->gus-nba-tools) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ollyl-s\appdata\local\anaconda3\lib\site-packages (from requests<3.0.0,>=2.32.3->nba_api->gus-nba-tools) (2025.4.26)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\ollyl-s\appdata\local\anaconda3\lib\site-packages (from pandas->gus-nba-tools) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ollyl-s\appdata\local\anaconda3\lib\site-packages (from pandas->gus-nba-tools) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\ollyl-s\appdata\local\anaconda3\lib\site-packages (from pandas->gus-nba-tools) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\ollyl-s\appdata\local\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas->gus-nba-tools) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install lightgbm
# Out:
# Requirement already satisfied: lightgbm in c:\users\ollyl-s\appdata\local\anaconda3\lib\site-packages (4.6.0)
# Requirement already satisfied: numpy>=1.17.0 in c:\users\ollyl-s\appdata\local\anaconda3\lib\site-packages (from lightgbm) (2.1.3)
# Requirement already satisfied: scipy in c:\users\ollyl-s\appdata\local\anaconda3\lib\site-packages (from lightgbm) (1.15.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install nba_api
# Out:
# Requirement already satisfied: nba_api in c:\users\ollyl-s\appdata\local\anaconda3\lib\site-packages (1.11.3)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: numpy>=2.1.0 in c:\users\ollyl-s\appdata\local\anaconda3\lib\site-packages (from nba_api) (2.1.3)
# Requirement already satisfied: pandas>=2.2.0 in c:\users\ollyl-s\appdata\local\anaconda3\lib\site-packages (from nba_api) (2.2.3)
# Requirement already satisfied: requests<3.0.0,>=2.32.3 in c:\users\ollyl-s\appdata\local\anaconda3\lib\site-packages (from nba_api) (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\ollyl-s\appdata\local\anaconda3\lib\site-packages (from requests<3.0.0,>=2.32.3->nba_api) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ollyl-s\appdata\local\anaconda3\lib\site-packages (from requests<3.0.0,>=2.32.3->nba_api) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\ollyl-s\appdata\local\anaconda3\lib\site-packages (from requests<3.0.0,>=2.32.3->nba_api) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ollyl-s\appdata\local\anaconda3\lib\site-packages (from requests<3.0.0,>=2.32.3->nba_api) (2025.4.26)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\ollyl-s\appdata\local\anaconda3\lib\site-packages (from pandas>=2.2.0->nba_api) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ollyl-s\appdata\local\anaconda3\lib\site-packages (from pandas>=2.2.0->nba_api) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\ollyl-s\appdata\local\anaconda3\lib\site-packages (from pandas>=2.2.0->nba_api) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\ollyl-s\appdata\local\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas>=2.2.0->nba_api) (1.17.0)

# %%
import pandas as pd
import numpy as np
from gus_nba_tools import NBASeasonDataCollector
from sklearn.preprocessing import LabelEncoder, PolynomialFeatures, StandardScaler
import optuna
from sklearn.model_selection import cross_val_score, StratifiedKFold, cross_val_predict
from xgboost import XGBClassifier
from sklearn.linear_model import LogisticRegression
from lightgbm import LGBMClassifier
from sklearn.svm import SVC
from sklearn.calibration import CalibratedClassifierCV
from sklearn.metrics import accuracy_score, confusion_matrix

# %%
collector = NBASeasonDataCollector(2015, 2024)

# %%
seasons_data = collector.collect_all_seasons(save_csv=True)
# Out:
# Building dataset for 2015-16...
#   - Fetching NBA advanced Per100 stats for 2015-16...
#   - Fetching BBRef positions from https://www.basketball-reference.com/leagues/NBA_2016_per_game.html...
#   - Merged 538/570 players with BBRef positions.
#   - After minutes filter: 459 players remain.
#   - Saved: nba_2015_2016_per100_adv_gwb.csv
#
# Building dataset for 2016-17...
#   - Fetching NBA advanced Per100 stats for 2016-17...
#   - Fetching BBRef positions from https://www.basketball-reference.com/leagues/NBA_2017_per_game.html...
#   - Merged 545/584 players with BBRef positions.
#   - After minutes filter: 457 players remain.
#   - Saved: nba_2016_2017_per100_adv_gwb.csv
#
# Building dataset for 2017-18...
#   - Fetching NBA advanced Per100 stats for 2017-18...
#   - Fetching BBRef positions from https://www.basketball-reference.com/leagues/NBA_2018_per_game.html...
#   - Merged 620/654 players with BBRef positions.
#   - After minutes filter: 465 players remain.
#   - Saved: nba_2017_2018_per100_adv_gwb.csv
#
# Building dataset for 2018-19...
#   - Fetching NBA advanced Per100 stats for 2018-19...
#   - Fetching BBRef positions from https://www.basketball-reference.com/leagues/NBA_2019_per_game.html...
#   - Merged 652/690 players with BBRef positions.
#   - After minutes filter: 524 players remain.
#   - Saved: nba_2018_2019_per100_adv_gwb.csv
#
# Building dataset for 2019-20...
#   - Fetching NBA advanced Per100 stats for 2019-20...
#   - Fetching BBRef positions from https://www.basketball-reference.com/leagues/NBA_2020_per_game.html...
#   - Merged 609/641 players with BBRef positions.
#   - After minutes filter: 467 players remain.
#   - Saved: nba_2019_2020_per100_adv_gwb.csv
#
# Building dataset for 2020-21...
#   - Fetching NBA advanced Per100 stats for 2020-21...
#   - Fetching BBRef positions from https://www.basketball-reference.com/leagues/NBA_2021_per_game.html...
#   - Merged 675/701 players with BBRef positions.
#   - After minutes filter: 555 players remain.
#   - Saved: nba_2020_2021_per100_adv_gwb.csv
#
# Building dataset for 2021-22...
#   - Fetching NBA advanced Per100 stats for 2021-22...
#   - Fetching BBRef positions from https://www.basketball-reference.com/leagues/NBA_2022_per_game.html...
#   - Merged 775/800 players with BBRef positions.
#   - After minutes filter: 553 players remain.
#   - Saved: nba_2021_2022_per100_adv_gwb.csv
#
# Building dataset for 2022-23...
#   - Fetching NBA advanced Per100 stats for 2022-23...
#   - Fetching BBRef positions from https://www.basketball-reference.com/leagues/NBA_2023_per_game.html...
#   - Merged 654/675 players with BBRef positions.
#   - After minutes filter: 537 players remain.
#   - Saved: nba_2022_2023_per100_adv_gwb.csv
#
# Building dataset for 2023-24...
#   - Fetching NBA advanced Per100 stats for 2023-24...
#   - Fetching BBRef positions from https://www.basketball-reference.com/leagues/NBA_2024_per_game.html...
#   - Merged 691/717 players with BBRef positions.
#   - After minutes filter: 534 players remain.
#   - Saved: nba_2023_2024_per100_adv_gwb.csv
#
# Building dataset for 2024-25...
#   - Fetching NBA advanced Per100 stats for 2024-25...
#   - Fetching BBRef positions from https://www.basketball-reference.com/leagues/NBA_2025_per_game.html...
#   - Merged 707/727 players with BBRef positions.
#   - After minutes filter: 563 players remain.
#   - Saved: nba_2024_2025_per100_adv_gwb.csv
#
# Done! Collected 10 seasons.

# %%
df = collector.get_combined_data()
df.to_csv('2015-2025_player_data.csv', index=True)

# %%
df = df.drop_duplicates(subset=['PLAYER_NAME', 'Season'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3993 entries, 0 to 5113
# Data columns (total 29 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PLAYER_ID    3993 non-null   int64
#  1   PLAYER_NAME  3993 non-null   object
#  2   TEAM_ID      3993 non-null   int64
#  3   GP           3993 non-null   int64
#  4   MIN          3993 non-null   float64
#  5   PTS          3993 non-null   float64
#  6   REB          3993 non-null   float64
#  7   AST          3993 non-null   float64
#  8   STL          3993 non-null   float64
#  9   BLK          3993 non-null   float64
#  10  TOV          3993 non-null   float64
#  11  FG_PCT       3993 non-null   float64
#  12  FG3_PCT      3993 non-null   float64
#  13  FT_PCT       3993 non-null   float64
#  14  FGA          3993 non-null   float64
#  15  FG3A         3993 non-null   float64
#  16  USG_PCT      3993 non-null   float64
#  17  AST_PCT      3993 non-null   float64
#  18  REB_PCT      3993 non-null   float64
#  19  OREB_PCT     3993 non-null   float64
#  20  DREB_PCT     3993 non-null   float64
#  21  TS_PCT       3993 non-null   float64
#  22  EFG_PCT      3993 non-null   float64
#  23  OFF_RATING   3993 non-null   float64
#  24  DEF_RATING   3993 non-null   float64
#  25  NET_RATING   3993 non-null   float64
#  26  Pos          3993 non-null   object
#  27  Position3    3993 non-null   object
#  28  Season       3993 non-null   int64
# dtypes: float64(22), int64(4), object(3)
# memory usage: 935.9+ KB

# %%
df['position_label'] = df['Position3'].map({'Guard': 0, 'Wing': 1, 'Big': 2})

# %%
feature_cols = [
    col for col in df.columns 
    if col not in ["PLAYER_ID", "PLAYER_NAME", "TEAM_ID", "Position3", "Position", "position_label", "Pos", "SEASON", "START_YEAR"]
]

# %%
X_train = df.loc[df.Season <= 2023][feature_cols]
y_train = df.loc[df.Season <= 2023]["position_label"]

# %%
X_test = df.loc[df.Season == 2024][feature_cols]
y_test = df.loc[df.Season == 2024]["position_label"]

# %%
scaler = StandardScaler()
X_train_scaled = pd.DataFrame(scaler.fit_transform(X_train), columns=X_train.columns, index=X_train.index)
X_test_scaled = pd.DataFrame(scaler.transform(X_test), columns=X_test.columns, index= X_test.index)

# %%
def objective_svm(trial):
    base_params = {
        "C": trial.suggest_float("C", 0.01, 10.0, log=True),
        "kernel": trial.suggest_categorical("kernel", ["linear", "rbf", "poly"]),
        "gamma": trial.suggest_categorical("gamma", ["scale", "auto"]),
        "probability": True}
    
    model = SVC(**base_params)
    
    score = cross_val_score(model, X_train_scaled, y_train, cv=5, scoring="accuracy").mean()
    return score
    
study_svm = optuna.create_study(direction="maximize")
study_svm.optimize(objective_svm, n_trials=50)
best_params_svm = study_svm.best_params
# Out:
# [I 2026-01-13 18:43:33,999] A new study created in memory with name: no-name-0d2eea16-fda0-4b3a-8fb2-b2a2e4f2236c
# [I 2026-01-13 18:43:41,179] Trial 0 finished with value: 0.7986873000614589 and parameters: {'C': 2.780472334152691, 'kernel': 'linear', 'gamma': 'auto'}. Best is trial
 'kernel': 'linear', 'gamma': 'auto'}. Best is trial 22 with value: 0.8014966827930724.
# [I 2026-01-13 18:45:37,390] Trial 26 finished with value: 0.8003742691901603 and parameters: {'C': 0.5173547727634611, 'kernel': 'linear', 'gamma': 'scale'}. Best is trial 22 with value: 0.8014966827930724.
# [I 2026-01-13 18:45:40,110] Trial 27 finished with value: 0.7984095529256031 and parameters: {'C': 0.26285078690401276, 'kernel': 'linear', 'gamma': 'auto'}. Best is trial 22 with value: 0.8014966827930724.
# [I 2026-01-13 18:45:46,270] Trial 28 finished with value: 0.7753943615361584 and parameters: {'C': 0.10104898012406174, 'kernel': 'rbf', 'gamma': 'auto'}. Best is trial 22 with value: 0.8014966827930724.
# [I 2026-01-13 18:45:49,781] Trial 29 finished with value: 0.8014970767606411 and parameters: {'C': 0.632615671160341, 'kernel': 'linear', 'gamma': 'auto'}. Best is trial 29 with value: 0.8014970767606411.
# [I 2026-01-13 18:45:56,470] Trial 30 finished with value: 0.7986873000614589 and parameters: {'C': 2.5483950077326387, 'kernel': 'linear', 'gamma': 'auto'}. Best is trial 29 with value: 0.8014970767606411.
# [I 2026-01-13 18:45:59,188] Trial 31 finished with value: 0.800374663157729 and parameters: {'C': 0.3110263944969236, 'kernel': 'linear', 'gamma': 'auto'}. Best is trial 29 with value: 0.8014970767606411.
# [I 2026-01-13 18:46:02,483] Trial 32 finished with value: 0.8017775816694771 and parameters: {'C': 0.5999833379543412, 'kernel': 'linear', 'gamma': 'auto'}. Best is trial 32 with value: 0.8017775816694771.
# [I 2026-01-13 18:46:06,231] Trial 33 finished with value: 0.8006547740989962 and parameters: {'C': 0.6744103588682913, 'kernel': 'linear', 'gamma': 'auto'}. Best is trial 32 with value: 0.8017775816694771.
# [I 2026-01-13 18:46:10,085] Trial 34 finished with value: 0.8003738752225917 and parameters: {'C': 0.6758120406714913, 'kernel': 'linear', 'gamma': 'auto'}. Best is trial 32 with value: 0.8017775816694771.
# [I 2026-01-13 18:46:14,272] Trial 35 finished with value: 0.7737089682777314 and parameters: {'C': 0.859678816687828, 'kernel': 'poly', 'gamma': 'auto'}. Best is trial 32 with value: 0.8017775816694771.
# [I 2026-01-13 18:46:16,929] Trial 36 finished with value: 0.7961643317522101 and parameters: {'C': 0.17645315949502446, 'kernel': 'linear', 'gamma': 'auto'}. Best is trial 32 with value: 0.8017775816694771.
# [I 2026-01-13 18:46:20,651] Trial 37 finished with value: 0.7664150527128607 and parameters: {'C': 0.4232041210713196, 'kernel': 'poly', 'gamma': 'auto'}. Best is trial 32 with value: 0.8017775816694771.
# [I 2026-01-13 18:46:24,399] Trial 38 finished with value: 0.8000941582488931 and parameters: {'C': 0.33619440310374726, 'kernel': 'linear', 'gamma': 'auto'}. Best is trial 32 with value: 0.8017775816694771.
# [I 2026-01-13 18:46:27,929] Trial 39 finished with value: 0.7686602738862538 and parameters: {'C': 0.5805795782232895, 'kernel': 'poly', 'gamma': 'scale'}. Best is trial 32 with value: 0.8017775816694771.
# [I 2026-01-13 18:46:36,709] Trial 40 finished with value: 0.7981251083410814 and parameters: {'C': 3.5712871453392463, 'kernel': 'linear', 'gamma': 'auto'}. Best is trial 32 with value: 0.8017775816694771.
# [I 2026-01-13 18:46:40,499] Trial 41 finished with value: 0.8003742691901603 and parameters: {'C': 0.48689338733726445, 'kernel': 'linear', 'gamma': 'auto'}. Best is trial 32 with value: 0.8017775816694771.
# [I 2026-01-13 18:46:44,664] Trial 42 finished with value: 0.7986892698993019 and parameters: {'C': 1.018571723018034, 'kernel': 'linear', 'gamma': 'auto'}. Best is trial 32 with value: 0.8017775816694771.
# [I 2026-01-13 18:46:47,360] Trial 43 finished with value: 0.7964444426934774 and parameters: {'C': 0.20034650900090667, 'kernel': 'linear', 'gamma': 'auto'}. Best is trial 32 with value: 0.8017775816694771.
# [I 2026-01-13 18:46:50,447] Trial 44 finished with value: 0.7992522495548167 and parameters: {'C': 0.41920914531019693, 'kernel': 'linear', 'gamma': 'auto'}. Best is trial 32 with value: 0.8017775816694771.
# [I 2026-01-13 18:46:55,983] Trial 45 finished with value: 0.7902674251855587 and parameters: {'C': 0.686486491842347, 'kernel': 'rbf', 'gamma': 'auto'}. Best is trial 32 with value: 0.8017775816694771.
# [I 2026-01-13 18:47:01,750] Trial 46 finished with value: 0.7978453913673825 and parameters: {'C': 1.8293071751691088, 'kernel': 'linear', 'gamma': 'auto'}. Best is trial 32 with value: 0.8017775816694771.
# [I 2026-01-13 18:47:05,884] Trial 47 finished with value: 0.7986892698993019 and parameters: {'C': 1.009043502926411, 'kernel': 'linear', 'gamma': 'scale'}. Best is trial 32 with value: 0.8017775816694771.
# [I 2026-01-13 18:47:10,069] Trial 48 finished with value: 0.7565867437792522 and parameters: {'C': 0.2625909064113493, 'kernel': 'poly', 'gamma': 'auto'}. Best is trial 32 with value: 0.8017775816694771.
# [I 2026-01-13 18:47:12,704] Trial 49 finished with value: 0.793637817734844 and parameters: {'C': 0.07754579824422028, 'kernel': 'linear', 'gamma': 'auto'}. Best is trial 32 with value: 0.8017775816694771.

# %%
print(best_params_svm)
# Out:
# {'C': 0.5999833379543412, 'kernel': 'linear', 'gamma': 'auto'}

# %%
def objective_lgbm(trial):
    params = {
        "num_leaves": trial.suggest_int("num_leaves", 20, 150),
        "max_depth": trial.suggest_int("max_depth", 3, 15),
        "learning_rate": trial.suggest_float("learning_rate", 0.01, 0.3),
        "n_estimators": trial.suggest_int("n_estimators", 50, 500),
    }
    model = LGBMClassifier(**params, verbose = -1)
    
    score = cross_val_score(model, X_train_scaled, y_train, cv=5, scoring="accuracy").mean()
    return score

study_lgbm = optuna.create_study(direction="maximize")
study_lgbm.optimize(objective_lgbm, n_trials=50)
best_params_lgbm = study_lgbm.best_params
# Out:
# [I 2026-01-13 18:47:12,726] A new study created in memory with name: no-name-269b2787-d35e-42dd-8430-95e25688a49f
# C:\Users\OllyL-S\AppData\Local\anaconda3\Lib\site-packages\joblib\externals\loky\backend\context.py:136: UserWarning: Could not find the number of physical cores for the following reason:
# found 0 physical cores < 1
# Returning the number of logical cores instead. You can silence this warning by setting LOKY_MAX_CPU_COUNT to the number of cores you want to use.
#   warnings.warn(
#   File "C:\Users
. Best is trial 22 with value: 0.7894227587185023.
# [I 2026-01-13 18:49:52,449] Trial 37 finished with value: 0.7793222181949981 and parameters: {'num_leaves': 97, 'max_depth': 8, 'learning_rate': 0.2828076566538364, 'n_estimators': 388}. Best is trial 22 with value: 0.7894227587185023.
# [I 2026-01-13 18:49:57,580] Trial 38 finished with value: 0.7810017019398964 and parameters: {'num_leaves': 80, 'max_depth': 9, 'learning_rate': 0.2242368117177943, 'n_estimators': 306}. Best is trial 22 with value: 0.7894227587185023.
# [I 2026-01-13 18:49:59,296] Trial 39 finished with value: 0.7745449674582787 and parameters: {'num_leaves': 117, 'max_depth': 5, 'learning_rate': 0.2031591164635004, 'n_estimators': 177}. Best is trial 22 with value: 0.7894227587185023.
# [I 2026-01-13 18:50:02,328] Trial 40 finished with value: 0.7838087208660983 and parameters: {'num_leaves': 128, 'max_depth': 10, 'learning_rate': 0.12982380073593175, 'n_estimators': 86}. Best is trial 22 with value: 0.7894227587185023.
# [I 2026-01-13 18:50:07,158] Trial 41 finished with value: 0.7829672061395906 and parameters: {'num_leaves': 106, 'max_depth': 10, 'learning_rate': 0.26350849647526836, 'n_estimators': 115}. Best is trial 22 with value: 0.7894227587185023.
# [I 2026-01-13 18:50:11,543] Trial 42 finished with value: 0.7871747797721291 and parameters: {'num_leaves': 101, 'max_depth': 11, 'learning_rate': 0.23970277914086321, 'n_estimators': 143}. Best is trial 22 with value: 0.7894227587185023.
# [I 2026-01-13 18:50:18,309] Trial 43 finished with value: 0.780998156231779 and parameters: {'num_leaves': 90, 'max_depth': 12, 'learning_rate': 0.22327365060518978, 'n_estimators': 146}. Best is trial 22 with value: 0.7894227587185023.
# [I 2026-01-13 18:50:22,575] Trial 44 finished with value: 0.7840919835479142 and parameters: {'num_leaves': 112, 'max_depth': 15, 'learning_rate': 0.21589890910921514, 'n_estimators': 72}. Best is trial 22 with value: 0.7894227587185023.
# [I 2026-01-13 18:50:28,182] Trial 45 finished with value: 0.7885812439919946 and parameters: {'num_leaves': 100, 'max_depth': 13, 'learning_rate': 0.19331310305809388, 'n_estimators': 162}. Best is trial 22 with value: 0.7894227587185023.
# [I 2026-01-13 18:50:33,754] Trial 46 finished with value: 0.781559166049451 and parameters: {'num_leaves': 99, 'max_depth': 14, 'learning_rate': 0.15916417244069858, 'n_estimators': 169}. Best is trial 22 with value: 0.7894227587185023.
# [I 2026-01-13 18:50:40,333] Trial 47 finished with value: 0.7821260853806515 and parameters: {'num_leaves': 78, 'max_depth': 13, 'learning_rate': 0.18632049591696023, 'n_estimators': 191}. Best is trial 22 with value: 0.7894227587185023.
# [I 2026-01-13 18:50:45,565] Trial 48 finished with value: 0.7810017019398963 and parameters: {'num_leaves': 136, 'max_depth': 13, 'learning_rate': 0.23819516047985834, 'n_estimators': 259}. Best is trial 22 with value: 0.7894227587185023.
# [I 2026-01-13 18:50:48,414] Trial 49 finished with value: 0.7815638936602738 and parameters: {'num_leaves': 65, 'max_depth': 14, 'learning_rate': 0.06641005577261733, 'n_estimators': 103}. Best is trial 22 with value: 0.7894227587185023.

# %%
print(best_params_lgbm)
# Out:
# {'num_leaves': 115, 'max_depth': 11, 'learning_rate': 0.23642005529963217, 'n_estimators': 236}

# %%
def objective_logreg(trial):
    params = {
        "C": trial.suggest_float("C", 0.01, 10.0, log=True), 
        "solver": trial.suggest_categorical("solver", ["lbfgs", "liblinear"]),
        "max_iter": 10000
    }
    model = LogisticRegression(**params)
    score = cross_val_score(model, X_train_scaled, y_train, cv=5, scoring="accuracy").mean()
    return score

study_logreg = optuna.create_study(direction="maximize")
study_logreg.optimize(objective_logreg, n_trials=50)
best_params_logreg = study_logreg.best_params
# Out:
# [I 2026-01-13 18:50:48,439] A new study created in memory with name: no-name-e63efadb-9ec0-49cd-a541-973ee8697133
# [I 2026-01-13 18:50:48,855] Trial 0 finished with value: 0.79167507130813 and parameters: {'C': 2.289923594955042, 'solver': 'lbfgs'}. Best is trial 0 with value: 0
 'solver': 'lbfgs'}. Best is trial 27 with value: 0.7947645649810108.
# [I 2026-01-13 18:50:55,482] Trial 34 finished with value: 0.7821343586995919 and parameters: {'C': 0.20197419921267654, 'solver': 'liblinear'}. Best is trial 27 with value: 0.7947645649810108.
# [I 2026-01-13 18:50:55,647] Trial 35 finished with value: 0.7922368690609389 and parameters: {'C': 0.965578387847992, 'solver': 'lbfgs'}. Best is trial 27 with value: 0.7947645649810108.
# [I 2026-01-13 18:50:55,817] Trial 36 finished with value: 0.7801704303701719 and parameters: {'C': 0.3709247240584421, 'solver': 'liblinear'}. Best is trial 27 with value: 0.7947645649810108.
# [I 2026-01-13 18:50:56,113] Trial 37 finished with value: 0.794201585325496 and parameters: {'C': 6.075466003461437, 'solver': 'lbfgs'}. Best is trial 27 with value: 0.7947645649810108.
# [I 2026-01-13 18:50:56,291] Trial 38 finished with value: 0.7939214743842287 and parameters: {'C': 0.3962446031170291, 'solver': 'lbfgs'}. Best is trial 27 with value: 0.7947645649810108.
# [I 2026-01-13 18:50:56,446] Trial 39 finished with value: 0.7812920560379469 and parameters: {'C': 0.10374601970479097, 'solver': 'liblinear'}. Best is trial 27 with value: 0.7947645649810108.
# [I 2026-01-13 18:50:56,611] Trial 40 finished with value: 0.7925177679373434 and parameters: {'C': 0.9109849764960941, 'solver': 'lbfgs'}. Best is trial 27 with value: 0.7947645649810108.
# [I 2026-01-13 18:50:56,775] Trial 41 finished with value: 0.7944840600721749 and parameters: {'C': 0.5171763378830055, 'solver': 'lbfgs'}. Best is trial 27 with value: 0.7947645649810108.
# [I 2026-01-13 18:50:56,869] Trial 42 finished with value: 0.7866251950139466 and parameters: {'C': 0.039039279251957305, 'solver': 'lbfgs'}. Best is trial 27 with value: 0.7947645649810108.
# [I 2026-01-13 18:50:57,010] Trial 43 finished with value: 0.7930795656901524 and parameters: {'C': 0.2328613911230556, 'solver': 'lbfgs'}. Best is trial 27 with value: 0.7947645649810108.
# [I 2026-01-13 18:50:57,105] Trial 44 finished with value: 0.7913965362371369 and parameters: {'C': 0.11081859050179828, 'solver': 'lbfgs'}. Best is trial 27 with value: 0.7947645649810108.
# [I 2026-01-13 18:50:57,346] Trial 45 finished with value: 0.7939210804166601 and parameters: {'C': 7.092303129623317, 'solver': 'lbfgs'}. Best is trial 27 with value: 0.7947645649810108.
# [I 2026-01-13 18:50:57,522] Trial 46 finished with value: 0.7922376569960761 and parameters: {'C': 0.7898909013352515, 'solver': 'lbfgs'}. Best is trial 27 with value: 0.7947645649810108.
# [I 2026-01-13 18:50:57,762] Trial 47 finished with value: 0.7798887435586301 and parameters: {'C': 3.0637230644546483, 'solver': 'liblinear'}. Best is trial 27 with value: 0.7947645649810108.
# [I 2026-01-13 18:50:57,917] Trial 48 finished with value: 0.7939214743842287 and parameters: {'C': 0.38425625955710885, 'solver': 'lbfgs'}. Best is trial 27 with value: 0.7947645649810108.
# [I 2026-01-13 18:50:58,132] Trial 49 finished with value: 0.7927982728461793 and parameters: {'C': 1.3377862335580386, 'solver': 'lbfgs'}. Best is trial 27 with value: 0.7947645649810108.

# %%
print(best_params_logreg)
# Out:
# {'C': 0.5051828297976904, 'solver': 'lbfgs'}

# %%
lgbm_best = LGBMClassifier(**best_params_lgbm)
logreg_best = LogisticRegression(**best_params_logreg)
svm_best = SVC(**best_params_svm, probability=True)

lgbm_best.fit(X_train_scaled, y_train)
logreg_best.fit(X_train_scaled, y_train)
svm_best.fit(X_train_scaled, y_train)
# Out:
# SVC(C=0.5999833379543412, gamma='auto', kernel='linear', probability=True)

# %%
oof_lgbm = cross_val_predict(lgbm_best, X_train_scaled, y_train, cv=5, method="predict_proba")
oof_logreg = cross_val_predict(logreg_best, X_train_scaled, y_train, cv=5, method="predict_proba")
oof_svm = cross_val_predict(svm_best, X_train_scaled, y_train, cv=5, method="predict_proba")

Z_train = np.hstack([oof_lgbm, oof_logreg, oof_svm])

meta = LogisticRegression(max_iter=1000)
meta.fit(Z_train, y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %%
P_test = np.hstack([
    lgbm_best.predict_proba(X_test_scaled),
    logreg_best.predict_proba(X_test_scaled),
    svm_best.predict_proba(X_test_scaled)
])

# %%
y_pred = meta.predict(P_test)

# %%
print(y_test.value_counts())
# Out:
# position_label
# 0    197
# 2    165
# 1     69
# Name: count, dtype: int64

# %%
acc = accuracy_score(y_test, y_pred)
print("Accuracy:", acc)

# Confusion matrix
cm = confusion_matrix(y_test, y_pred)
print("\nConfusion Matrix:\n", cm)
# Out:
# Accuracy: 0.7888631090487239
#
# Confusion Matrix:
#  [[169  19   9]
#  [ 24  27  18]
#  [  5  16 144]]

# %%
probs = meta.predict_proba(P_test)

result = X_test.copy()
result["PLAYER_NAME"] = df.loc[X_test.index, "PLAYER_NAME"]
result["True_Label"] = y_test
result["Pred_Label"] = y_pred
result["P_Guard"] = probs[:, 1]
result["P_Wing"] = probs[:, 2]
result["P_Big"] = probs[:, 0]

result["entropy"] = -(
    result["P_Guard"] * np.log(result["P_Guard"] + 1e-9) +
    result["P_Wing"] * np.log(result["P_Wing"] + 1e-9) +
    result["P_Big"] * np.log(result["P_Big"] + 1e-9)
)

hybrids = pd.DataFrame(result.sort_values("entropy", ascending=False))

# %%
hybrids.head(10)
# Out:
#       GP   MIN   PTS   REB  AST  STL  BLK  TOV  FG_PCT  FG3_PCT  ...  \
# 4719  68  47.4  14.6   9.9  9.1  2.4  1.7  4.2   0.424    0.325  ...
# 4773  66  46.1  15.7   8.9  5.4  2.1  0.8  2.9   0.475    0.423  ...
# 4750  82  47.8  21.7   6.6  2.9  0.8  0.3  1.1   0.508    0.433  ...
# 5099  36  47.7  14.4   9.1  4.0  1.9  0.5  2.6   0.468    0.341  ...
# 4709  54  47.4  11.6  10.4  5.0  1.4  0.3  2.4   0.383    0.254  ...
# 4751  74  49.3  13.0   6.8  3.0  1.8  1.0  1.5   0.458    0.382  ...
# 4715  63  49.0  14.8   6.7  2.4  1.6  0.6  1.5   0.448    0.411  ...
# 4574  60  48.1  28.1   7.0  4.1  1.6  1.3  2.6   0.448    0.374  ...
# 4772  66  48.3  20.1  10.2  5.9  2.2  0.5  3.5   0.461    0.311  ...
# 5092  60  48.5  19.3   8.1  4.5  1.3  0.3  2.7   0.406    0.351  ...
#
#       DEF_RATING  NET_RATING  Season          PLAYER_NAME  True_Label  \
# 4719       108.8         6.6    2024       Draymond Green           2
# 4773       111.2         3.8    2024         Jake LaRavia           2
# 4750       115.6        -1.2    2024      Harrison Barnes           2
# 5099       112.0       -12.4    2024    Wendell Moore Jr.           0
# 4709       102.9         6.0    2024         Dillon Jones           1
# 4751       110.4         1.4    2024    Haywood Highsmith           1
# 4715       110.3         8.8    2024  Dorian Finney-Smith           2
# 4574       111.7        -2.3    2024       Andrew Wiggins           1
# 4772       113.9        -6.0    2024     Jaime Jaquez Jr.           1
# 5092       113.4       -10.2    2024        Tyrese Martin           0
#
#       Pred_Label   P_Guard    P_Wing     P_Big   entropy
# 4719           2  0.318541  0.393036  0.288424  1.090055
# 4773           2  0.375720  0.393314  0.230966  1.073293
# 4750           1  0.441596  0.293334  0.265071  1.072650
# 5099           2  0.385613  0.387839  0.226548  1.071184
# 4709           1  0.417663  0.353201  0.229136  1.069854
# 4751           1  0.442612  0.329723  0.227665  1.063501
# 4715           1  0.440281  0.334321  0.225398  1.063299
# 4574           1  0.458391  0.223404  0.318205  1.056756
# 4772           2  0.396587  0.403869  0.199544  1.054570
# 5092           1  0.452962  0.210734  0.336304  1.053352
#
# [10 rows x 31 columns]

# %%
decode = {0: "Guard", 1: "Wing", 2: "Big"}

hybrids["True_Pos"] = hybrids["True_Label"].map(decode)
hybrids["Pred_Pos"] = hybrids["Pred_Label"].map(decode)

# %%
hybrids[['PLAYER_NAME', 'True_Pos', 'Pred_Pos', 'P_Guard', 'P_Wing', 'P_Big', 'entropy']].head(10).to_csv('final_positionless.csv', index = False)
